# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('candy.csv', encoding = 'ISO-8859-1')

# %%
#df.head()

# %%
df.set_index('Internal ID', inplace = True)

# %%
#df.head(2)

# %%
df = df.rename(columns={'Q3: AGE': 'age', 'Q1: GOING OUT?': 'going out', 'Q2: GENDER': 'gender'} )

# %%
#df.head(2)

# %%
df.age.describe()
# Out:
# count     2376
# unique     106
# top         40
# freq        92
# Name: age, dtype: object

# %%
#df.age.value_counts()

# %%
df.age.isnull().sum()
# Out:
# 84

# %%
#df[df.age.isnull()]

# %%
#df[df.age.notnull()].head()

# %%
df['age'] = df['age'].str.replace('\D+', '  ')

# %%
#df.age.value_counts()

# %%
df.age.isnull().sum()
# Out:
# 84

# %%
df['age'] = df['age'].str.replace(' ', '')

# %%
#df.age.value_counts()

# %%
df.age.isnull().sum()
# Out:
# 84

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
df.age.dtype
# Out:
# dtype('float64')

# %%
df.age.isnull().sum()
# Out:
# 100

# %%
#df.age.value_counts()

# %%
#df['age'] = df['age'].astype(int)

# %%
#df.age.dtype

# %%
df[df['age'] > 90]
# Out:
#             going out              gender     age Q4: COUNTRY  \
# Internal ID
# 90274268           No                Male  4555.0          US
# 90274337           No               Other   312.0      Canada
# 90274994           No  I'd rather not say    99.0          US
# 90275982           No                Male   394.0     US of A
# 90276469           No  I'd rather not say   102.0           A
# 90278741           No  I'd rather not say  2450.0         USA
# 90279273           No  I'd rather not say   100.0         NaN
# 90279712           No  I'd rather not say   100.0         Usa
# 90279807          Yes  I'd rather not say  1000.0    Atlantis
# 90287278           No                Male  7012.0         USA
#
#             Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Internal ID
# 90274268                                  NC                JOY
# 90274337                                  BC                MEH
# ...

# %%
#df['age'] = df['age'].replace((df['age'] > 100), np.nan)

# %%
#df[df['age'] > 100]

# %%
df.age.isnull().sum()
# Out:
# 100

# %%
#df.age.value_counts()

# %%
#df['age'] = df['age'].replace([100.0 - 7012.0], np.nan)

# %%
#df.age.value_counts()

# %%
df.age.isnull().sum()
# Out:
# 100

# %%
df.age.mean()
# Out:
# 48.626694915254234

# %%
df.age.max()
# Out:
# 7012.0

# %%
df.age.min()
# Out:
# 1.0

# %%
#df.age.value_counts()

# %%
df['age'] = df['age'].replace(2450, np.mean((24,50)))

# %%
df['age'] = df['age'].replace(4555, np.mean((45,55)))

# %%
df['age'] = df['age'].replace(394, 39)

# %%
df['age'] = df['age'].replace(7012, 71)

# %%
df[df['age'] > 90]
# Out:
#             going out              gender     age Q4: COUNTRY  \
# Internal ID
# 90274337           No               Other   312.0      Canada
# 90274994           No  I'd rather not say    99.0          US
# 90276469           No  I'd rather not say   102.0           A
# 90279273           No  I'd rather not say   100.0         NaN
# 90279712           No  I'd rather not say   100.0         Usa
# 90279807          Yes  I'd rather not say  1000.0    Atlantis
#
#             Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Internal ID
# 90274337                                  BC                MEH
# 90274994                                  NY                MEH
# 90276469                                   A                MEH
# 90279273                                 NaN                NaN
# 90279712                            New york                MEH
# 90279807              Emerald City, Petrolia                MEH
#
# ...

# %%
#df.age.value_counts()

# %%
#df['age'].replace((df['age'] > 90), np.nan)

# %%
#df.age.isnull().sum()

# %%
mean_age = df['age'].mean(skipna=True)
mean_age
# Out:
# 42.603813559322035

# %%
#df[df['age'] > 90]

# %%
df['age'] = df.age.mask((df['age'] > 90), mean_age)

# %%
df['age'] = df.age.mask((df['age'] < 5), mean_age)

# %%
df[df['age'] > 90]
# Out:
# Empty DataFrame
# ...

# %%
df[df['age'] < 5]
# Out:
# Empty DataFrame
# ...

# %%
#df.age.value_counts()

# %%
df.age.max()
# Out:
# 90.0

# %%
df.age.min()
# Out:
# 5.0

# %%
df[df['age'] < 10]
# Out:
#             going out  gender  age    Q4: COUNTRY  \
# Internal ID
# 90273811          Yes  Female  9.0            usa
# 90273934          Yes  Female  6.0  United States
# 90275243          Yes  Female  7.0      Australia
# 90275672          Yes    Male  9.0        'merica
# 90276709          Yes    Male  8.0  United States
# 90277137          Yes    Male  9.0         Canada
# 90277406           No  Female  5.0            USA
# 90278444          Yes  Female  8.0            USA
# 90278873          Yes    Male  7.0         CANADA
# 90279571           No    Male  9.0            USA
# 90279648          Yes    Male  6.0            USA
#
#             Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# Internal ID
# 90273811                                  va                NaN
# 90273934                            Colorado                MEH
# 90275243                             Sydney                 NaN
# 90275672                              Merlin                JOY
# ...

# %%
#df.age.value_counts()

# %%
mean_age1 = df['age'].mean(skipna=True)
mean_age1
# Out:
# 42.03747217035335

# %%
df.age.nunique()
# Out:
# 76

# %%
df.age.unique()
# Out:
# array([        nan, 44.        , 49.        , 40.        , 23.        ,
#        53.        , 33.        , 43.        , 56.        , 64.        ,
#        37.        , 59.        , 48.        , 54.        , 36.        ,
#        45.        , 25.        , 34.        , 35.        , 38.        ,
#        58.        , 50.        , 47.        , 16.        , 52.        ,
#        63.        , 65.        , 41.        , 27.        , 31.        ,
#        61.        , 46.        , 42.        , 62.        , 29.        ,
#        39.        , 32.        , 28.        , 69.        , 67.        ,
#        30.        , 22.        , 26.        , 51.        , 70.        ,
#        24.        , 18.        , 19.        , 57.        , 60.        ,
#        66.        , 12.        , 55.        , 72.        , 21.        ,
#        11.        ,  9.        , 68.        , 20.        ,  6.        ,
#        10.        , 71.        , 90.        , 13.        , 42.60381356,
# ...

# %%
df.age.isnull().sum()
# Out:
# 100

# %%
df['age'].fillna(value = mean_age1, inplace = True)

# %%
df.age.isnull().sum()
# Out:
# 0

# %%
df.age.dtype
# Out:
# dtype('float64')

# %%
df['age'] = df['age'].round(0).astype(int)

# %%
df.age.dtype
# Out:
# dtype('int64')

# %%
df.age.value_counts()
# Out:
# 42    179
# 43     95
# 40     92
# 37     90
# 34     90
# 36     79
# 35     77
# 38     76
# 44     76
# 45     75
# 33     75
# 41     74
# 50     73
# 39     70
# 49     69
# 32     68
# 48     64
# 47     63
# 30     62
# 53     57
# 46     56
# 52     50
# 56     46
# 31     45
# 27     45
# 51     41
# 28     37
# 54     36
# 58     34
# 60     32
#      ...
# 18     10
# 66      9
# 12      9
# 23      9
# 68      8
# 15      8
# 70      8
# 71      7
# 11      7
# 72      6
# 67      6
# 13      6
# 69      5
# 17      5
# 9       4
# 16      4
# 73      4
# 75      3
# 10      3
# 19      3
# 14      2
# 8       2
# 90      2
# 6       2
# 76      2
# 7       2
# 74      1
# 88      1
# 5       1
# 77      1
# Name: age, Length: 75, dtype: int64

# %%
df
# Out:
#             going out              gender  age     Q4: COUNTRY  \
# Internal ID
# 90258773          NaN                 NaN   42             NaN
# 90272821           No                Male   44            USA
# 90272829          NaN                Male   49             USA
# 90272840           No                Male   40              us
# 90272841           No                Male   23             usa
# 90272852           No                Male   42             NaN
# 90272853           No                Male   53             usa
# 90272854           No                Male   33          canada
# 90272858           No                Male   40          Canada
# 90272859           No              Female   53              Us
# 90272861          Yes                Male   43             NaN
# 90272865           No                Male   56          Canada
# 90272866           No                Male   64              US
# 90272867          Yes                Male   43          Murica
# ...

# %%
df['going out'].describe()
# Out:
# count     2350
# unique       2
# top         No
# freq      2038
# Name: going out, dtype: object

# %%
df['going out'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
df['going out'].isnull().sum()
# Out:
# 110

# %%
df['gender'].describe()
# Out:
# count     2419
# unique       4
# top       Male
# freq      1467
# Name: gender, dtype: object

# %%
df['gender'].unique()
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
df['gender'].isnull().sum()
# Out:
# 41

# %%
df.shape
# Out:
# (2460, 119)

# %%
multiple_null = df.dropna(thresh=20)
multiple_null.shape
# Out:
# (1797, 119)
